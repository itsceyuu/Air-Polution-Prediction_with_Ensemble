# %% [markdown]
# # Load and inspect the provided preprocessed ISPU dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./datasets/ispu_preprocessed_3.csv")

# Basic inspection outputs
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nInfo:")
print(df.info())

print("\nMissing values per column:")
print(df.isna().sum().sort_values(ascending=False).head(20))

print("\nSample rows:")
print(df.head())

df = df.rename(columns={
    "pm_sepuluh": "pm10",
    "pm_duakomalima": "pm25",
    "sulfur_dioksida": "so2",
    "karbon_monoksida": "co",
    "ozon": "o3",
    "nitrogen_dioksida": "no2"
})

pollutant_cols = [
    "pm10",
    "pm25",
    "so2",
    "co",
    "o3",
    "no2"
]

# pollutant_cols = [
#     "pm_sepuluh",
#     "pm_duakomalima",
#     "sulfur_dioksida",
#     "karbon_monoksida",
#     "ozon",
#     "nitrogen_dioksida"
# ]

print("\nMissing values (pollutants):")
print(df[pollutant_cols].isna().sum())

print("\nBasic statistics (pollutants):")
print(df[pollutant_cols].describe())

# Check unique categories and stations
print("\nUnique kategori:", df['kategori'].unique())
print("Unique stasiun:", df['stasiun'].unique())
# Out:
# Shape: (15356, 12)
#
# Columns:
# ['periode_data', 'tanggal', 'stasiun', 'pm_sepuluh', 'pm_duakomalima', 'sulfur_dioksida', 'karbon_monoksida', 'ozon', 'nitrogen_dioksida', 'max', 'parameter_pencemar_kritis', 'kategori']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15356 entries, 0 to 15355
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   periode_data               15356 non-null  int64
#  1   tanggal                    15356 non-null  object
#  2   stasiun                    15356 non-null  object
#  3   pm_sepuluh                 14648 non-null  float64
#  4   pm_duakomalima             6579 non-null   float64
#  5   sulfur_dioksida            15057 non-null  float64
#  6   karbon_monoksida           15150 non-null  float64
#  7   ozon                       15013 non-null  float64
#  8   nitrogen_dioksida          15046 non-null  float64
#  9   max                        15356 non-null  float64
#  10  parameter_pencemar_kritis  15312 non-null  object
#  11  kategori                   15356 non-null  object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.4+ MB
# None
#
# Missing values per column:
# pm_duakomalima               8777
# pm_sepuluh                    708
# ozon                          343
# nitrogen_dioksida             310
# sulfur_dioksida               299
# karbon_monoksida              206
# parameter_pencemar_kritis      44
# periode_data                    0
# tanggal                         0
# stasiun                         0
# max                             0
# kategori                        0
# dtype: int64
#
# Sample rows:
#    periode_data     tanggal stasiun  pm_sepuluh  pm_duakomalima  \
# 0        201001  2010-01-01    DKI1        60.0             NaN
# 1        201001  2010-01-02    DKI1        32.0             NaN
# 2        201001  2010-01-03    DKI1        27.0             NaN
# 3        201001  2010-01-04    DKI1        22.0             NaN
# 4        201001  2010-01-05    DKI1        25.0             NaN
#
#    sulfur_dioksida  karbon_monoksida  ozon  nitrogen_dioksida   max  \
# 0              4.0              73.0  27.0               14.0  73.0
# 1              2.0              16.0  33.0                9.0  33.0
# 2              2.0              19.0  20.0                9.0  27.0
# 3              2.0              16.0  15.0                6.0  22.0
# 4              2.0              17.0  15.0                8.0  25.0
#
#   parameter_pencemar_kritis kategori
# 0                        CO   SEDANG
# 1                        O3     BAIK
# 2                      PM10     BAIK
# 3                      PM10     BAIK
# 4                      PM10     BAIK
#
# Missing values (pollutants):
# pm10     708
# pm25    8777
# so2      299
# co       206
# o3       343
# no2      310
# dtype: int64
#
# Basic statistics (pollutants):
#                pm10         pm25           so2            co            o3  \
# count  14648.000000  6579.000000  15057.000000  15150.000000  15013.000000
# mean      54.104861    75.840249     27.862987     20.287195     53.486312
# std       18.969806    24.128926     15.567588     12.183173     40.603767
# min        2.000000    10.000000      0.000000      0.000000      2.000000
# 25%       42.000000    60.000000     15.000000     11.000000     25.000000
# 50%       55.000000    77.000000     26.000000     18.000000     42.000000
# 75%       65.000000    91.000000     38.000000     26.000000     71.000000
# max      187.000000   287.000000    112.000000    134.000000    314.000000
#
#                 no2
# count  15046.000000
# mean      17.270903
# std       11.557827
# min        0.000000
# 25%       10.000000
# 50%       15.000000
# 75%       22.000000
# max      202.000000
#
# Unique kategori: ['SEDANG' 'BAIK' 'TIDAK SEHAT' 'SANGAT TIDAK SEHAT' 'BERBAHAYA']
# Unique stasiun: ['DKI1' 'DKI2' 'DKI4' 'DKI3' 'DKI5']

# %% [markdown]
# ## Trying BRITS

# %%
# !pip install pypots

# %%
df["tanggal"] = pd.to_datetime(df["tanggal"])
df = df.sort_values(["stasiun", "tanggal"])

sequences = []
station_lengths = []

for station in df["stasiun"].unique():
    seq = df[df["stasiun"] == station][pollutant_cols].values
    sequences.append(seq)
    station_lengths.append(len(seq))

X = np.array(sequences, dtype=object)

# %%
max_len = max(len(seq) for seq in sequences)
n_features = len(pollutant_cols)

X = np.full((len(sequences), max_len, n_features), np.nan)

for i, seq in enumerate(sequences):
    X[i, :len(seq), :] = seq

# %%
from pypots.imputation import BRITS

brits = BRITS(
    n_steps=max_len,
    n_features=n_features,
    rnn_hidden_size=64,
    batch_size=4,
    epochs=10,
    device="cpu"
)

train_set = {"X": X}
brits.fit(train_set)

X_imputed = brits.impute({"X": X})
# Out:
# 2026-02-06 22:21:15 [INFO]: Using the given device: cpu
# 2026-02-06 22:21:15 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2026-02-06 22:21:15 [INFO]: Using customized MAE as the training loss function.
# 2026-02-06 22:21:15 [INFO]: Using customized MSE as the validation metric function.
# 2026-02-06 22:21:15 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 41,936
# 2026-02-06 22:21:19 [INFO]: Epoch 001 - training loss (MAE): 77.9196
# 2026-02-06 22:21:23 [INFO]: Epoch 002 - training loss (MAE): 73.1785
# 2026-02-06 22:21:27 [INFO]: Epoch 003 - training loss (MAE): 68.1332
# 2026-02-06 22:21:32 [INFO]: Epoch 004 - training loss (MAE): 71.4050
# 2026-02-06 22:21:36 [INFO]: Epoch 005 - training loss (MAE): 76.4520
# 2026-02-06 22:21:40 [INFO]: Epoch 006 - training loss (MAE): 70.7308
# 2026-02-06 22:21:45 [INFO]: Epoch 007 - training loss (MAE): 73.4964
# 2026-02-06 22:21:49 [INFO]: Epoch 008 - training loss (MAE): 71.1272
# 2026-02-06 22:21:54 [INFO]: Epoch 009 - training loss (MAE): 66.1659
# 2026-02-06 22:21:58 [INFO]: Epoch 010 - training loss (MAE): 74.6223
# 2026-02-06 22:21:58 [INFO]: Finished training. The best model is from epoch#9.

# %%
imputed_list = []

for i, station in enumerate(df["stasiun"].unique()):
    seq_len = len(df[df["stasiun"] == station])
    
    temp = df[df["stasiun"] == station].copy()
    temp[pollutant_cols] = X_imputed[i, :seq_len, :]
    
    imputed_list.append(temp)

df_imputed = pd.concat(imputed_list).sort_values(["stasiun","tanggal"])

# %%
df_imputed[pollutant_cols].isna().sum()
# Out:
# pm10    0
# pm25    0
# so2     0
# co      0
# o3      0
# no2     0
# dtype: int64

# %%
df_imputed.pivot_table(index="tanggal", columns="stasiun", values="pm25").corr()
# Out:
# stasiun      DKI1      DKI2      DKI3      DKI4      DKI5
# stasiun
# DKI1     1.000000  0.971644  0.905143  0.906454  0.771657
# DKI2     0.971644  1.000000  0.895011  0.906838  0.786701
# DKI3     0.905143  0.895011  1.000000  0.840255  0.715102
# DKI4     0.906454  0.906838  0.840255  1.000000  0.682180
# DKI5     0.771657  0.786701  0.715102  0.682180  1.000000

# %%
# df_imputed.to_csv("ispu_imputed_BRITS.csv", index=False)

# %%
df["tanggal"] = pd.to_datetime(df["tanggal"])
df = df.sort_values("tanggal")

# %%
df["year"] = df["tanggal"].dt.year
df["month"] = df["tanggal"].dt.month
df["day"] = df["tanggal"].dt.day
df["dayofweek"] = df["tanggal"].dt.dayofweek
df["weekofyear"] = df["tanggal"].dt.isocalendar().week.astype(int)
df["quarter"] = df["tanggal"].dt.quarter
df["is_weekend"] = (df["dayofweek"] >= 5).astype(int)

# %%
df
# Out:
#        periode_data    tanggal stasiun  pm10   pm25   so2    co     o3   no2  \
# 0            201001 2010-01-01    DKI1  60.0   51.0   4.0  73.0   27.0  14.0
# 13411        201001 2010-01-01    DKI5  57.0   62.0  39.0  35.0  197.0  11.0
# 6375         201001 2010-01-01    DKI3  69.0   89.0   0.0  19.0   80.0   6.0
# 9719         201001 2010-01-01    DKI4  27.0  101.0   8.0  22.0   45.0  10.0
# 2894         201001 2010-01-01    DKI2  27.0   60.0   8.0  22.0   45.0  10.0
# ...             ...        ...     ...   ...    ...   ...   ...    ...   ...
# 2893         202508 2025-08-31    DKI1  42.0   70.0  29.0  12.0   15.0  24.0
# 9718         202508 2025-08-31    DKI3  28.0   60.0  53.0   8.0   19.0  39.0
# 13410        202508 2025-08-31    DKI4  47.0   59.0  27.0  10.0   18.0  17.0
# 6374         202508 2025-08-31    DKI2  76.0   72.0  45.0  16.0   21.0  16.0
# 16813        202508 2025-08-31    DKI5  37.0   65.0  25.0   9.0   21.0  34.0
#
#         max parameter_pencemar_kritis kategori  year  month  day  dayofweek  \
# 0      73.0                        CO   SEDANG  2010      1    1          4
# 13411   0.0                       NaN     BAIK  2010      1    1          4
# 6375    0.0                       NaN     BAIK  2010      1    1          4
# 9719    0.0                       NaN     BAIK  2010      1    1          4
# 2894    0.0                       NaN     BAIK  2010      1    1          4
# ...     ...                       ...      ...   ...    ...  ...        ...
# 2893   70.0                      PM25   SEDANG  2025      8   31          6
# 9718   60.0                      PM25   SEDANG  2025      8   31          6
# 13410  59.0                      PM25   SEDANG  2025      8   31          6
# 6374   72.0                      PM25   SEDANG  2025      8   31          6
# 16813  65.0                      PM25   SEDANG  2025      8   31          6
#
#        weekofyear  quarter  is_weekend
# 0              53        1           0
# 13411          53        1           0
# 6375           53        1           0
# 9719           53        1           0
# 2894           53        1           0
# ...           ...      ...         ...
# 2893           35        3           1
# 9718           35        3           1
# 13410          35        3           1
# 6374           35        3           1
# 16813          35        3           1
#
# [16814 rows x 19 columns]

# %%
time_features = [
    "year",
    "month",
    "day",
    "dayofweek",
    "weekofyear",
    "quarter",
    "is_weekend",
    "stasiun"
]

# %%
df[time_features + ["pm10","pm25","so2","co","o3","no2"]].head()
# Out:
#        year  month  day  dayofweek  weekofyear  quarter  is_weekend stasiun  \
# 0      2010      1    1          4          53        1           0    DKI1
# 13411  2010      1    1          4          53        1           0    DKI5
# 6375   2010      1    1          4          53        1           0    DKI3
# 9719   2010      1    1          4          53        1           0    DKI4
# 2894   2010      1    1          4          53        1           0    DKI2
#
#        pm10   pm25   so2    co     o3   no2
# 0      60.0   51.0   4.0  73.0   27.0  14.0
# 13411  57.0   62.0  39.0  35.0  197.0  11.0
# 6375   69.0   89.0   0.0  19.0   80.0   6.0
# 9719   27.0  101.0   8.0  22.0   45.0  10.0
# 2894   27.0   60.0   8.0  22.0   45.0  10.0

# %%
split_date = df["tanggal"].quantile(0.8)

train = df[df["tanggal"] <= split_date]
test  = df[df["tanggal"] > split_date]

# %%
import catboost

# %%
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting prophet
#   Downloading prophet-1.3.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from prophet) (3.9.4)
# Requirement already satisfied: pandas>=1.0.4 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from prophet) (2.3.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.83-py3-none-any.whl.metadata (50 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: importlib_resources in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from importlib_resources->prophet) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0.4->prophet) (2025.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.15.0)
# Downloading prophet-1.3.0-py3-none-macosx_11_0_arm64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 9.7 MB/s  0:00:01m eta 0:00:01
# Downloading holidays-0.83-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.8 MB/s  0:00:00
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, stanio, holidays, cmdstanpy, prophet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [prophet]m4/5 [prophet]]
# Successfully installed cmdstanpy-1.3.0 holidays-0.83 prophet-1.3.0 stanio-0.5.1 tqdm-4.67.3
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from prophet import Prophet

def forecast_pollutant(df, station, pollutant, future_dates):
    df_st = df[df["stasiun"] == station][["tanggal", pollutant]].copy()
    df_st.columns = ["ds", "y"]

    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=True,
        daily_seasonality=False
    )

    model.fit(df_st)

    future = pd.DataFrame({"ds": future_dates})
    forecast = model.predict(future)

    return forecast[["ds", "yhat"]]

# %%
split_date = "2024-01-01"

df_train_ts = df[df["tanggal"] < split_date].copy()
df_test_ts  = df[df["tanggal"] >= split_date].copy()

# %%
df_forecasted = df_test_ts[["tanggal","stasiun"]].copy()

for pol in pollutant_cols:
    print(f"Forecasting {pol}...")
    
    all_preds = []
    
    for station in df_test_ts["stasiun"].unique():
        dates = df_test_ts[df_test_ts["stasiun"] == station]["tanggal"]
        
        fc = forecast_pollutant(df_train_ts, station, pol, dates)
        fc["stasiun"] = station
        
        all_preds.append(fc)
    
    all_preds = pd.concat(all_preds)
    
    df_forecasted = df_forecasted.merge(
        all_preds.rename(columns={"ds":"tanggal", "yhat":pol}),
        on=["tanggal","stasiun"],
        how="left"
    )
# Out:
# 19:25:58 - cmdstanpy - INFO - Chain [1] start processing
# Forecasting pm10...
# 19:26:00 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:00 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:01 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:01 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:01 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:01 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:01 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:01 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:02 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:02 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:02 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# Forecasting pm25...
# 19:26:02 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:02 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:02 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:02 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:02 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:03 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:03 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:03 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:03 - cmdstanpy - INFO - Chain [1] start processing
# Forecasting so2...
# 19:26:03 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:03 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:03 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:04 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:04 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:04 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:05 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:05 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# Forecasting co...
# 19:26:05 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:05 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:05 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:05 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:06 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:06 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:06 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:06 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:06 - cmdstanpy - INFO - Chain [1] start processing
# Forecasting o3...
# 19:26:06 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:07 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:07 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:07 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:08 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:08 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:08 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting no2...
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:08 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:08 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:08 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:08 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:09 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:09 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 19:26:09 - cmdstanpy - INFO - Chain [1] start processing
# 19:26:09 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)

# %%
from catboost import CatBoostClassifier

model = CatBoostClassifier()
model.load_model("catboost_kategori.cbm")

feature_cols = model.feature_names_

# %%
df_forecasted
# Out:
#         tanggal stasiun       pm10        pm25        so2         co  \
# 0    2024-01-01    DKI1  39.463289   73.001936  50.613535   4.922721
# 1    2024-01-01    DKI2  37.742404   71.060779  32.557821   6.530574
# 2    2024-01-01    DKI4  46.478064   90.779084  32.038545  18.851930
# 3    2024-01-01    DKI5  28.662926   58.911396  22.974011  13.636418
# 4    2024-01-01    DKI3  39.575833   67.094354  50.639917   7.503768
# ...         ...     ...        ...         ...        ...        ...
# 3040 2025-08-31    DKI1  61.588365   90.808861  62.837959   4.837714
# 3041 2025-08-31    DKI3  63.757047   69.098223  62.079669   4.414555
# 3042 2025-08-31    DKI4  74.655770  104.043526  27.908867  26.040610
# 3043 2025-08-31    DKI2  65.457672   80.003796  33.947012   3.464339
# 3044 2025-08-31    DKI5  44.560236   51.180159  23.901107  19.610526
#
#              o3        no2
# 0     18.285463  18.636982
# 1     10.007299  21.088254
# 2     10.452966  11.887249
# 3     20.894101  10.806930
# 4     -1.792920   7.445826
# ...         ...        ...
# 3040  34.815012  26.750065
# 3041  17.237722   4.569194
# 3042  16.047195  12.647919
# 3043   0.978447  23.899147
# 3044  71.217565  10.283031
#
# [3045 rows x 8 columns]

# %%
df_forecasted["year"] = df_test_ts["year"].values
df_forecasted["month"] = df_test_ts["month"].values
df_forecasted["day"] = df_test_ts["day"].values
df_forecasted["dayofweek"] = df_test_ts["dayofweek"].values
df_forecasted["weekofyear"] = df_test_ts["weekofyear"].values
df_forecasted["quarter"] = df_test_ts["quarter"].values
df_forecasted["is_weekend"] = df_test_ts["is_weekend"].values

# %%
df_forecasted
# Out:
#         tanggal stasiun       pm10        pm25        so2         co  \
# 0    2024-01-01    DKI1  39.463289   73.001936  50.613535   4.922721
# 1    2024-01-01    DKI2  37.742404   71.060779  32.557821   6.530574
# 2    2024-01-01    DKI4  46.478064   90.779084  32.038545  18.851930
# 3    2024-01-01    DKI5  28.662926   58.911396  22.974011  13.636418
# 4    2024-01-01    DKI3  39.575833   67.094354  50.639917   7.503768
# ...         ...     ...        ...         ...        ...        ...
# 3040 2025-08-31    DKI1  61.588365   90.808861  62.837959   4.837714
# 3041 2025-08-31    DKI3  63.757047   69.098223  62.079669   4.414555
# 3042 2025-08-31    DKI4  74.655770  104.043526  27.908867  26.040610
# 3043 2025-08-31    DKI2  65.457672   80.003796  33.947012   3.464339
# 3044 2025-08-31    DKI5  44.560236   51.180159  23.901107  19.610526
#
#              o3        no2  year  month  day  dayofweek  weekofyear  quarter  \
# 0     18.285463  18.636982  2024      1    1          0           1        1
# 1     10.007299  21.088254  2024      1    1          0           1        1
# 2     10.452966  11.887249  2024      1    1          0           1        1
# 3     20.894101  10.806930  2024      1    1          0           1        1
# 4     -1.792920   7.445826  2024      1    1          0           1        1
# ...         ...        ...   ...    ...  ...        ...         ...      ...
# 3040  34.815012  26.750065  2025      8   31          6          35        3
# 3041  17.237722   4.569194  2025      8   31          6          35        3
# 3042  16.047195  12.647919  2025      8   31          6          35        3
# 3043   0.978447  23.899147  2025      8   31          6          35        3
# 3044  71.217565  10.283031  2025      8   31          6          35        3
#
#       is_weekend
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3040           1
# 3041           1
# 3042           1
# 3043           1
# 3044           1
#
# [3045 rows x 15 columns]

# %%
X_fake_test = df_forecasted[feature_cols]
y_pred = model.predict(X_fake_test)

from sklearn.metrics import classification_report

y_true = df_test_ts["kategori"]

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         BAIK       0.47      0.21      0.29       380
#       SEDANG       0.79      0.88      0.83      2343
#  TIDAK SEHAT       0.23      0.18      0.20       322
#
#     accuracy                           0.72      3045
#    macro avg       0.50      0.42      0.44      3045
# weighted avg       0.69      0.72      0.70      3045

# %%
sample = pd.read_csv("sample_submission.csv")
sample.head()
# Out:
#                 id  category
# 0  2025-09-01_DKI1       NaN
# 1  2025-09-01_DKI2       NaN
# 2  2025-09-01_DKI3       NaN
# 3  2025-09-01_DKI4       NaN
# 4  2025-09-01_DKI5       NaN

# %%
sample[["tanggal", "stasiun_kode"]] = sample["id"].str.split("_", expand=True)

sample["tanggal"] = pd.to_datetime(sample["tanggal"])

# %%
sample
# Out:
#                   id  category    tanggal stasiun_kode
# 0    2025-09-01_DKI1       NaN 2025-09-01         DKI1
# 1    2025-09-01_DKI2       NaN 2025-09-01         DKI2
# 2    2025-09-01_DKI3       NaN 2025-09-01         DKI3
# 3    2025-09-01_DKI4       NaN 2025-09-01         DKI4
# 4    2025-09-01_DKI5       NaN 2025-09-01         DKI5
# ..               ...       ...        ...          ...
# 450  2025-11-30_DKI1       NaN 2025-11-30         DKI1
# 451  2025-11-30_DKI2       NaN 2025-11-30         DKI2
# 452  2025-11-30_DKI3       NaN 2025-11-30         DKI3
# 453  2025-11-30_DKI4       NaN 2025-11-30         DKI4
# 454  2025-11-30_DKI5       NaN 2025-11-30         DKI5
#
# [455 rows x 4 columns]

# %%
from prophet import Prophet

def forecast_station(df_hist, station, target_dates):
    df_s = df_hist[df_hist["stasiun"] == station].copy()
    df_s = df_s.sort_values("tanggal")

    forecasts = []

    for pol in pollutant_cols:
        df_p = df_s[["tanggal", pol]].dropna()
        df_p.columns = ["ds", "y"]

        m = Prophet()
        m.fit(df_p)

        future = pd.DataFrame({"ds": target_dates})
        fc = m.predict(future)[["ds", "yhat"]]
        fc.columns = ["tanggal", pol]

        forecasts.append(fc)

    # gabungkan semua polutan
    df_fc = forecasts[0]
    for f in forecasts[1:]:
        df_fc = df_fc.merge(f, on="tanggal")

    df_fc["stasiun"] = station
    return df_fc

# %%
all_forecasts = []

for station in sample["stasiun_kode"].unique():
    target_dates = sample[sample["stasiun_kode"] == station]["tanggal"].values
    df_fc = forecast_station(df, station, target_dates)
    all_forecasts.append(df_fc)

df_forecasted = pd.concat(all_forecasts, ignore_index=True)
df_forecasted.head()
# Out:
# 20:09:26 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:26 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:26 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:26 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:27 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:27 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:27 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:27 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:27 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:27 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:27 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:28 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:28 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:28 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:28 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:29 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:29 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:29 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:29 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:29 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:29 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:30 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:30 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:30 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:30 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:31 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:31 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:31 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:31 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:32 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:32 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:32 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:33 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:33 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:34 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:34 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:34 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:35 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:35 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:35 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:35 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:35 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:36 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:36 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:36 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 20:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:09:36 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
#      tanggal       pm10       pm25        so2         co         o3  \
# 0 2025-09-01  53.272534  80.402058  26.327209  18.840674  19.592837
# 1 2025-09-02  54.270946  80.185300  27.015627  19.776844  18.503192
# 2 2025-09-03  54.876824  80.560976  27.179653  20.286136  19.727644
# 3 2025-09-04  54.993791  80.511244  27.426414  20.078263  20.057687
# 4 2025-09-05  55.402798  79.950646  27.137119  20.094219  20.934656
#
#          no2 stasiun
# 0  38.065682    DKI1
# 1  39.303561    DKI1
# 2  40.097976    DKI1
# 3  39.913029    DKI1
# 4  39.254798    DKI1

# %%
feature_cols = model.feature_names_
X_submit = df_forecasted[feature_cols]
sample["category"] = model.predict(X_submit).ravel()

# %%
feature_cols
# Out:
# ['stasiun', 'pm10', 'pm25', 'so2', 'co', 'o3', 'no2']

# %%
submission = sample[["id", "category"]]
submission.to_csv("submission5_prophet.csv", index=False)

# %%
sample
# Out:
#                   id category    tanggal stasiun_kode
# 0    2025-09-01_DKI1   SEDANG 2025-09-01         DKI1
# 1    2025-09-01_DKI2   SEDANG 2025-09-01         DKI2
# 2    2025-09-01_DKI3   SEDANG 2025-09-01         DKI3
# 3    2025-09-01_DKI4   SEDANG 2025-09-01         DKI4
# 4    2025-09-01_DKI5   SEDANG 2025-09-01         DKI5
# ..               ...      ...        ...          ...
# 450  2025-11-30_DKI1   SEDANG 2025-11-30         DKI1
# 451  2025-11-30_DKI2   SEDANG 2025-11-30         DKI2
# 452  2025-11-30_DKI3   SEDANG 2025-11-30         DKI3
# 453  2025-11-30_DKI4   SEDANG 2025-11-30         DKI4
# 454  2025-11-30_DKI5   SEDANG 2025-11-30         DKI5
#
# [455 rows x 4 columns]

# %%
pollutant_cols = ["pm10","pm25","so2","co","o3","no2"]

med = df_filled.groupby("stasiun")[pollutant_cols].median().reset_index()
sample = sample.merge(med, on="stasiun", how="left")

# %%
feature_cols = model.feature_names_
X_submit = sample[feature_cols]

sample["category"] = model.predict(X_submit).ravel()

# feature_cols = model.feature_names_
# X_submit = sample[feature_cols]

# pred = model.predict(X_submit).ravel()

# sample["category"] = pred

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
import pickle

model_xgb = XGBClassifier()
model_xgb.load_model("xgb_kategori.json")

# load encoder
le_station = pickle.load(open("le_station.pkl", "rb"))
le_target = pickle.load(open("le_target.pkl", "rb"))

# misal ini data hasil forecasting prophet (sample)
df_sample = df_forecasted.copy()

# %%
df_sample["stasiun"] = le_station.transform(df_sample["stasiun"])

# %%
X_submit = df_sample[feature_cols]
y_pred_num = model_xgb.predict(X_submit)

# %%
y_pred_label = le_target.inverse_transform(y_pred_num)
df_sample["kategori"] = y_pred_label

# %%
df_sample
# Out:
#        tanggal       pm10       pm25        so2         co         o3  \
# 0   2025-09-01  53.272534  80.402058  26.327209  18.840674  19.592837
# 1   2025-09-02  54.270946  80.185300  27.015627  19.776844  18.503192
# 2   2025-09-03  54.876824  80.560976  27.179653  20.286136  19.727644
# 3   2025-09-04  54.993791  80.511244  27.426414  20.078263  20.057687
# 4   2025-09-05  55.402798  79.950646  27.137119  20.094219  20.934656
# ..         ...        ...        ...        ...        ...        ...
# 450 2025-11-26  29.008590  79.920267  31.965587  11.886022  28.227834
# 451 2025-11-27  29.644199  79.184113  31.998058  11.947746  28.038554
# 452 2025-11-28  29.204838  78.549243  31.738331  11.721516  25.994905
# 453 2025-11-29  28.621046  77.426131  31.818083  11.561295  25.105164
# 454 2025-11-30  27.471892  77.221257  31.417936  11.637631  21.431290
#
#            no2  stasiun kategori
# 0    38.065682        0   SEDANG
# 1    39.303561        0   SEDANG
# 2    40.097976        0   SEDANG
# 3    39.913029        0   SEDANG
# 4    39.254798        0   SEDANG
# ..         ...      ...      ...
# 450  20.420846        4   SEDANG
# 451  20.232600        4   SEDANG
# 452  20.223026        4   SEDANG
# 453  19.361081        4   SEDANG
# 454  18.060228        4   SEDANG
#
# [455 rows x 9 columns]

# %%
df_sample.to_csv("submission_notclean.csv", index=False)

# %%
sample["category"] = le_target.inverse_transform(y_pred_num)

# %%
sample
# Out:
#                   id category    tanggal stasiun_kode
# 0    2025-09-01_DKI1   SEDANG 2025-09-01         DKI1
# 1    2025-09-01_DKI2   SEDANG 2025-09-01         DKI2
# 2    2025-09-01_DKI3   SEDANG 2025-09-01         DKI3
# 3    2025-09-01_DKI4   SEDANG 2025-09-01         DKI4
# 4    2025-09-01_DKI5   SEDANG 2025-09-01         DKI5
# ..               ...      ...        ...          ...
# 450  2025-11-30_DKI1   SEDANG 2025-11-30         DKI1
# 451  2025-11-30_DKI2   SEDANG 2025-11-30         DKI2
# 452  2025-11-30_DKI3   SEDANG 2025-11-30         DKI3
# 453  2025-11-30_DKI4   SEDANG 2025-11-30         DKI4
# 454  2025-11-30_DKI5   SEDANG 2025-11-30         DKI5
#
# [455 rows x 4 columns]

# %%
submission = sample[["id", "category"]]
submission.to_csv("submission6_xgb.csv", index=False)

# %%
print("\nUnique kategori:", df_sample['kategori'].unique())
# Out:
# Unique kategori: ['SEDANG' 'BAIK']

# %%
feature_cols = model_xgb.feature_names_
X_submit_xgb = df_sample[feature_cols]
sample["category"] = model_xgb.predict(X_submit).ravel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 feature_cols = model_xgb.feature_names_
#       2 X_submit_xgb = df_sample[feature_cols]
#       3 sample["category"] = model_xgb.predict(X_submit).ravel()
#
# AttributeError: 'XGBClassifier' object has no attribute 'feature_names_'

# %%
submission = sample[["id", "category"]]
submission.to_csv("submission5_prophet.csv", index=False)
