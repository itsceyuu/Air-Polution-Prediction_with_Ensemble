# %% [markdown]
# ## ini nyoba prophet pake data 5 kategori

# %%
# Load and inspect the provided preprocessed ISPU dataset
import pandas as pd

df = pd.read_csv("./datasets/ispu_imputed_fixed.csv")

# Basic inspection outputs
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nInfo:")
print(df.info())

print("\nMissing values per column:")
print(df.isna().sum().sort_values(ascending=False).head(20))

print("\nSample rows:")
print(df.head())

df = df.rename(columns={
    "pm_sepuluh": "pm10",
    "pm_duakomalima": "pm25",
    "sulfur_dioksida": "so2",
    "karbon_monoksida": "co",
    "ozon": "o3",
    "nitrogen_dioksida": "no2"
})

pollutant_cols = [
    "pm10",
    "pm25",
    "so2",
    "co",
    "o3",
    "no2"
]

print("\nMissing values (pollutants):")
print(df[pollutant_cols].isna().sum())

print("\nBasic statistics (pollutants):")
print(df[pollutant_cols].describe())

# Check unique categories and stations
print("\nUnique kategori:", df['kategori'].unique())
print("Unique stasiun:", df['stasiun'].unique())
# Out:
# Shape: (15347, 12)
#
# Columns:
# ['tanggal', 'stasiun', 'pm_sepuluh', 'pm_duakomalima', 'sulfur_dioksida', 'karbon_monoksida', 'ozon', 'nitrogen_dioksida', 'periode_data', 'max', 'parameter_pencemar_kritis', 'kategori']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15347 entries, 0 to 15346
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tanggal                    15347 non-null  object
#  1   stasiun                    15347 non-null  object
#  2   pm_sepuluh                 15347 non-null  float64
#  3   pm_duakomalima             15347 non-null  float64
#  4   sulfur_dioksida            15347 non-null  float64
#  5   karbon_monoksida           15347 non-null  float64
#  6   ozon                       15347 non-null  float64
#  7   nitrogen_dioksida          15347 non-null  float64
#  8   periode_data               15347 non-null  int64
#  9   max                        15347 non-null  float64
#  10  parameter_pencemar_kritis  15303 non-null  object
#  11  kategori                   15347 non-null  object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.4+ MB
# None
#
# Missing values per column:
# parameter_pencemar_kritis    44
# tanggal                       0
# stasiun                       0
# pm_sepuluh                    0
# pm_duakomalima                0
# sulfur_dioksida               0
# karbon_monoksida              0
# ozon                          0
# nitrogen_dioksida             0
# periode_data                  0
# max                           0
# kategori                      0
# dtype: int64
#
# Sample rows:
#       tanggal stasiun  pm_sepuluh  pm_duakomalima  sulfur_dioksida  \
# 0  2010-01-01    DKI1   46.000000        71.58465         3.000000
# 1  2010-01-02    DKI1   39.666667        71.58465         2.666667
# 2  2010-01-03    DKI1   27.000000        71.58465         2.000000
# 3  2010-01-04    DKI1   24.666667        71.58465         2.000000
# 4  2010-01-05    DKI1   25.666667        71.58465         2.333333
#
#    karbon_monoksida       ozon  nitrogen_dioksida  periode_data   max  \
# 0         44.500000  30.000000          11.500000        201001  73.0
# 1         36.000000  26.666667          10.666667        201001  33.0
# 2         17.000000  22.666667           8.000000        201001  27.0
# 3         17.333333  16.666667           7.666667        201001  22.0
# 4         18.333333  16.333333           8.333333        201001  25.0
#
#   parameter_pencemar_kritis kategori
# 0                        CO   SEDANG
# 1                        O3     BAIK
# 2                      PM10     BAIK
# 3                      PM10     BAIK
# 4                      PM10     BAIK
#
# Missing values (pollutants):
# pm10    0
# pm25    0
# so2     0
# co      0
# o3      0
# no2     0
# dtype: int64
#
# Basic statistics (pollutants):
#                pm10          pm25           so2            co            o3  \
# count  15347.000000  15347.000000  15347.000000  15347.000000  15347.000000
# mean      53.632962     75.704033     27.907156     20.007620     52.699982
# std       16.484777     14.772448     15.141898     10.630050     36.672190
# min        4.333333     11.000000      0.000000      1.000000      3.000000
# 25%       44.000000     70.503356     16.000000     11.896952     25.333333
# 50%       54.986165     74.221068     26.000000     17.888889     43.666667
# 75%       63.666667     84.873677     38.000000     26.000000     71.666667
# max      148.333333    251.000000     77.000000     86.947456    297.666667
#
#                 no2
# count  15347.000000
# mean      17.200745
# std       10.564151
# min        0.666667
# 25%       10.333333
# 50%       15.333333
# 75%       21.333333
# max      136.000000
#
# Unique kategori: ['SEDANG' 'BAIK' 'TIDAK SEHAT' 'SANGAT TIDAK SEHAT' 'BERBAHAYA']
# Unique stasiun: ['DKI1' 'DKI2' 'DKI4' 'DKI3' 'DKI5']

# %%
df["tanggal"] = pd.to_datetime(df["tanggal"])
df = df.sort_values("tanggal")

# %%
df["year"] = df["tanggal"].dt.year
df["month"] = df["tanggal"].dt.month
df["day"] = df["tanggal"].dt.day
df["dayofweek"] = df["tanggal"].dt.dayofweek
df["weekofyear"] = df["tanggal"].dt.isocalendar().week.astype(int)
df["quarter"] = df["tanggal"].dt.quarter
df["is_weekend"] = (df["dayofweek"] >= 5).astype(int)

# %%
df
# Out:
#          tanggal stasiun       pm10      pm25        so2         co  \
# 0     2010-01-01    DKI1  46.000000  71.58465   3.000000  44.500000
# 1     2010-01-02    DKI1  39.666667  71.58465   2.666667  36.000000
# 2     2010-01-03    DKI1  27.000000  71.58465   2.000000  17.000000
# 3     2010-01-04    DKI1  24.666667  71.58465   2.000000  17.333333
# 4     2010-01-05    DKI1  25.666667  71.58465   2.333333  18.333333
# ...          ...     ...        ...       ...        ...        ...
# 15344 2025-08-31    DKI3  24.500000  59.50000  53.000000   8.000000
# 15345 2025-08-31    DKI4  42.500000  60.00000  27.500000   9.500000
# 15342 2025-08-31    DKI1  43.000000  73.50000  29.500000  12.000000
# 15343 2025-08-31    DKI2  40.993923  69.00000  43.000000  15.500000
# 15346 2025-08-31    DKI5  37.500000  68.50000  25.500000   9.000000
#
#               o3        no2  periode_data   max parameter_pencemar_kritis  \
# 0      30.000000  11.500000        201001  73.0                        CO
# 1      26.666667  10.666667        201001  33.0                        O3
# 2      22.666667   8.000000        201001  27.0                      PM10
# 3      16.666667   7.666667        201001  22.0                      PM10
# 4      16.333333   8.333333        201001  25.0                      PM10
# ...          ...        ...           ...   ...                       ...
# 15344  21.000000  42.500000        202508  60.0                      PM25
# 15345  20.000000  18.500000        202508  59.0                      PM25
# 15342  18.500000  27.500000        202508  70.0                      PM25
# 15343  21.500000  16.000000        202508  72.0                      PM25
# 15346  25.500000  37.000000        202508  65.0                      PM25
#
#       kategori  year  month  day  dayofweek  weekofyear  quarter  is_weekend
# 0       SEDANG  2010      1    1          4          53        1           0
# 1         BAIK  2010      1    2          5          53        1           1
# 2         BAIK  2010      1    3          6          53        1           1
# 3         BAIK  2010      1    4          0           1        1           0
# 4         BAIK  2010      1    5          1           1        1           0
# ...        ...   ...    ...  ...        ...         ...      ...         ...
# 15344   SEDANG  2025      8   31          6          35        3           1
# 15345   SEDANG  2025      8   31          6          35        3           1
# 15342   SEDANG  2025      8   31          6          35        3           1
# 15343   SEDANG  2025      8   31          6          35        3           1
# 15346   SEDANG  2025      8   31          6          35        3           1
#
# [15347 rows x 19 columns]

# %%
time_features = [
    "year",
    "month",
    "day",
    "dayofweek",
    "weekofyear",
    "quarter",
    "is_weekend",
    "stasiun"
]

# %%
df[time_features + ["pm10","pm25","so2","co","o3","no2"]].head()
# Out:
#    year  month  day  dayofweek  weekofyear  quarter  is_weekend stasiun  \
# 0  2010      1    1          4          53        1           0    DKI1
# 1  2010      1    2          5          53        1           1    DKI1
# 2  2010      1    3          6          53        1           1    DKI1
# 3  2010      1    4          0           1        1           0    DKI1
# 4  2010      1    5          1           1        1           0    DKI1
#
#         pm10      pm25       so2         co         o3        no2
# 0  46.000000  71.58465  3.000000  44.500000  30.000000  11.500000
# 1  39.666667  71.58465  2.666667  36.000000  26.666667  10.666667
# 2  27.000000  71.58465  2.000000  17.000000  22.666667   8.000000
# 3  24.666667  71.58465  2.000000  17.333333  16.666667   7.666667
# 4  25.666667  71.58465  2.333333  18.333333  16.333333   8.333333

# %%
split_date = df["tanggal"].quantile(0.8)

train = df[df["tanggal"] <= split_date]
test  = df[df["tanggal"] > split_date]

# %%
import catboost

# %%
# !pip install prophet

# %%
from prophet import Prophet

def forecast_pollutant(df, station, pollutant, future_dates):
    df_st = df[df["stasiun"] == station][["tanggal", pollutant]].copy()
    df_st.columns = ["ds", "y"]

    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=True,
        daily_seasonality=False
    )

    model.fit(df_st)

    future = pd.DataFrame({"ds": future_dates})
    forecast = model.predict(future)

    return forecast[["ds", "yhat"]]

# %%
split_date = "2024-01-01"

df_train_ts = df[df["tanggal"] < split_date].copy()
df_test_ts  = df[df["tanggal"] >= split_date].copy()

# %%
df_forecasted = df_test_ts[["tanggal","stasiun"]].copy()

for pol in pollutant_cols:
    print(f"Forecasting {pol}...")
    
    all_preds = []
    
    for station in df_test_ts["stasiun"].unique():
        dates = df_test_ts[df_test_ts["stasiun"] == station]["tanggal"]
        
        fc = forecast_pollutant(df_train_ts, station, pol, dates)
        fc["stasiun"] = station
        
        all_preds.append(fc)
    
    all_preds = pd.concat(all_preds)
    
    df_forecasted = df_forecasted.merge(
        all_preds.rename(columns={"ds":"tanggal", "yhat":pol}),
        on=["tanggal","stasiun"],
        how="left"
    )
# Out:
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# Forecasting pm10...
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:48 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:48 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:48 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:49 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:49 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting pm25...
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:49 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:49 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:50 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:50 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:50 - cmdstanpy - INFO - Chain [1] start processing
# Forecasting so2...
# 09:37:50 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:50 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:51 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:51 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:51 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:52 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting co...
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:52 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:52 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:53 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:53 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:53 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting o3...
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:53 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:54 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:54 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:54 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:54 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting no2...
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:55 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:55 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:55 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 09:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:56 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)

# %% [markdown]
# ## nyoba pake xgb

# %%
df_forecasted
# Out:
#         tanggal stasiun       pm10        pm25        so2         co  \
# 0    2024-01-01    DKI1  41.367492   72.377497  50.813794   5.219047
# 1    2024-01-01    DKI2  37.737434   70.594727  32.055401   7.890116
# 2    2024-01-01    DKI3  42.303475   67.588262  48.522416   8.755110
# 3    2024-01-01    DKI4  47.225545   92.469565  28.585385  19.396138
# 4    2024-01-01    DKI5  30.505511   68.416259  23.223022  13.777513
# ...         ...     ...        ...         ...        ...        ...
# 3022 2025-08-31    DKI3  64.526564   70.831201  61.244409   4.873161
# 3023 2025-08-31    DKI4  79.846741  107.980521  19.816248  26.065425
# 3024 2025-08-31    DKI1  61.402589   89.202343  62.491694   6.177513
# 3025 2025-08-31    DKI2  67.701601   81.555754  31.638538   4.484153
# 3026 2025-08-31    DKI5  48.380951   75.688810  22.162956  20.955479
#
#              o3        no2
# 0     18.488442  18.410958
# 1     10.004616  20.061563
# 2     -3.402949   5.595026
# 3     -2.298899   8.247818
# 4     22.389081  12.109866
# ...         ...        ...
# 3022  21.919447   5.054854
# 3023 -20.989639   4.953007
# 3024  34.803632  27.100432
# 3025   4.469093  25.024826
# 3026  79.764509  10.270282
#
# [3027 rows x 8 columns]

# %%
df_forecasted["year"] = df_test_ts["year"].values
df_forecasted["month"] = df_test_ts["month"].values
df_forecasted["day"] = df_test_ts["day"].values
df_forecasted["dayofweek"] = df_test_ts["dayofweek"].values
df_forecasted["weekofyear"] = df_test_ts["weekofyear"].values
df_forecasted["quarter"] = df_test_ts["quarter"].values
df_forecasted["is_weekend"] = df_test_ts["is_weekend"].values

# %%
df_forecasted
# Out:
#         tanggal stasiun       pm10        pm25        so2         co  \
# 0    2024-01-01    DKI1  41.367492   72.377497  50.813794   5.219047
# 1    2024-01-01    DKI2  37.737434   70.594727  32.055401   7.890116
# 2    2024-01-01    DKI3  42.303475   67.588262  48.522416   8.755110
# 3    2024-01-01    DKI4  47.225545   92.469565  28.585385  19.396138
# 4    2024-01-01    DKI5  30.505511   68.416259  23.223022  13.777513
# ...         ...     ...        ...         ...        ...        ...
# 3022 2025-08-31    DKI3  64.526564   70.831201  61.244409   4.873161
# 3023 2025-08-31    DKI4  79.846741  107.980521  19.816248  26.065425
# 3024 2025-08-31    DKI1  61.402589   89.202343  62.491694   6.177513
# 3025 2025-08-31    DKI2  67.701601   81.555754  31.638538   4.484153
# 3026 2025-08-31    DKI5  48.380951   75.688810  22.162956  20.955479
#
#              o3        no2  year  month  day  dayofweek  weekofyear  quarter  \
# 0     18.488442  18.410958  2024      1    1          0           1        1
# 1     10.004616  20.061563  2024      1    1          0           1        1
# 2     -3.402949   5.595026  2024      1    1          0           1        1
# 3     -2.298899   8.247818  2024      1    1          0           1        1
# 4     22.389081  12.109866  2024      1    1          0           1        1
# ...         ...        ...   ...    ...  ...        ...         ...      ...
# 3022  21.919447   5.054854  2025      8   31          6          35        3
# 3023 -20.989639   4.953007  2025      8   31          6          35        3
# 3024  34.803632  27.100432  2025      8   31          6          35        3
# 3025   4.469093  25.024826  2025      8   31          6          35        3
# 3026  79.764509  10.270282  2025      8   31          6          35        3
#
#       is_weekend
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3022           1
# 3023           1
# 3024           1
# 3025           1
# 3026           1
#
# [3027 rows x 15 columns]

# %%
from xgboost import XGBClassifier
import pickle

model_xgb = XGBClassifier()
model_xgb.load_model("xgb_5kategori_berbahaya.json")

# load encoder
le_station = pickle.load(open("./models/le_station_5kategori.pkl", "rb"))
le_target = pickle.load(open("./models/le_target_5kategori.pkl", "rb"))

# ini data hasil forecasting prophet (sample)
df_sample = df_forecasted.copy()

# %%
df_sample["stasiun"] = le_station.transform(df_sample["stasiun"])

# %%
feature_cols = pickle.load(open("./models/feature_cols.pkl", "rb"))

# %%
for c in feature_cols:
    df_sample[c] = pd.to_numeric(df_sample[c], errors="coerce")

X_submit = df_sample[feature_cols]
y_pred_num = model_xgb.predict(X_submit)

y_pred_label = le_target.inverse_transform(y_pred_num)
df_sample["kategori"] = y_pred_label

# %%
df_sample
# Out:
#         tanggal  stasiun       pm10        pm25        so2         co  \
# 0    2024-01-01        0  41.367492   72.377497  50.813794   5.219047
# 1    2024-01-01        1  37.737434   70.594727  32.055401   7.890116
# 2    2024-01-01        2  42.303475   67.588262  48.522416   8.755110
# 3    2024-01-01        3  47.225545   92.469565  28.585385  19.396138
# 4    2024-01-01        4  30.505511   68.416259  23.223022  13.777513
# ...         ...      ...        ...         ...        ...        ...
# 3022 2025-08-31        2  64.526564   70.831201  61.244409   4.873161
# 3023 2025-08-31        3  79.846741  107.980521  19.816248  26.065425
# 3024 2025-08-31        0  61.402589   89.202343  62.491694   6.177513
# 3025 2025-08-31        1  67.701601   81.555754  31.638538   4.484153
# 3026 2025-08-31        4  48.380951   75.688810  22.162956  20.955479
#
#              o3        no2  year  month  day  dayofweek  weekofyear  quarter  \
# 0     18.488442  18.410958  2024      1    1          0           1        1
# 1     10.004616  20.061563  2024      1    1          0           1        1
# 2     -3.402949   5.595026  2024      1    1          0           1        1
# 3     -2.298899   8.247818  2024      1    1          0           1        1
# 4     22.389081  12.109866  2024      1    1          0           1        1
# ...         ...        ...   ...    ...  ...        ...         ...      ...
# 3022  21.919447   5.054854  2025      8   31          6          35        3
# 3023 -20.989639   4.953007  2025      8   31          6          35        3
# 3024  34.803632  27.100432  2025      8   31          6          35        3
# 3025   4.469093  25.024826  2025      8   31          6          35        3
# 3026  79.764509  10.270282  2025      8   31          6          35        3
#
#       is_weekend     kategori
# 0              0       SEDANG
# 1              0       SEDANG
# 2              0       SEDANG
# 3              0       SEDANG
# 4              0       SEDANG
# ...          ...          ...
# 3022           1       SEDANG
# 3023           1  TIDAK SEHAT
# 3024           1       SEDANG
# 3025           1       SEDANG
# 3026           1       SEDANG
#
# [3027 rows x 16 columns]

# %%
X_fake_test = df_sample[feature_cols]
y_pred = model_xgb.predict(X_fake_test)

from sklearn.metrics import classification_report

y_true = le_target.transform(df_test_ts["kategori"])

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25       362
#            2       0.00      0.00      0.00         1
#            3       0.78      0.88      0.83      2343
#            4       0.19      0.17      0.18       321
#
#     accuracy                           0.72      3027
#    macro avg       0.37      0.30      0.31      3027
# weighted avg       0.69      0.72      0.69      3027
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## test ke sample submission

# %%
sample = pd.read_csv("sample_submission.csv")
sample.head()
# Out:
#                 id  category
# 0  2025-09-01_DKI1       NaN
# 1  2025-09-01_DKI2       NaN
# 2  2025-09-01_DKI3       NaN
# 3  2025-09-01_DKI4       NaN
# 4  2025-09-01_DKI5       NaN

# %%
sample[["tanggal", "stasiun_kode"]] = sample["id"].str.split("_", expand=True)

sample["tanggal"] = pd.to_datetime(sample["tanggal"])

# %%
sample
# Out:
#                   id  category    tanggal stasiun_kode
# 0    2025-09-01_DKI1       NaN 2025-09-01         DKI1
# 1    2025-09-01_DKI2       NaN 2025-09-01         DKI2
# 2    2025-09-01_DKI3       NaN 2025-09-01         DKI3
# 3    2025-09-01_DKI4       NaN 2025-09-01         DKI4
# 4    2025-09-01_DKI5       NaN 2025-09-01         DKI5
# ..               ...       ...        ...          ...
# 450  2025-11-30_DKI1       NaN 2025-11-30         DKI1
# 451  2025-11-30_DKI2       NaN 2025-11-30         DKI2
# 452  2025-11-30_DKI3       NaN 2025-11-30         DKI3
# 453  2025-11-30_DKI4       NaN 2025-11-30         DKI4
# 454  2025-11-30_DKI5       NaN 2025-11-30         DKI5
#
# [455 rows x 4 columns]

# %%
from prophet import Prophet

def forecast_station(df_hist, station, target_dates):
    df_s = df_hist[df_hist["stasiun"] == station].copy()
    df_s = df_s.sort_values("tanggal")

    forecasts = []

    for pol in pollutant_cols:
        df_p = df_s[["tanggal", pol]].dropna()
        df_p.columns = ["ds", "y"]

        m = Prophet()
        m.fit(df_p)

        future = pd.DataFrame({"ds": target_dates})
        fc = m.predict(future)[["ds", "yhat"]]
        fc.columns = ["tanggal", pol]

        forecasts.append(fc)

    # gabungkan semua polutan
    df_fc = forecasts[0]
    for f in forecasts[1:]:
        df_fc = df_fc.merge(f, on="tanggal")

    df_fc["stasiun"] = station
    return df_fc

# %%
hasil_forecast = []

for st in sample["stasiun_kode"].unique():
    target_dates = sample[sample["stasiun_kode"] == st]["tanggal"]

    df_fc = forecast_station(df, st, target_dates)
    hasil_forecast.append(df_fc)

df_forecast_sample = pd.concat(hasil_forecast).reset_index(drop=True)
# Out:
# 12:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:38 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:38 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:38 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:38 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:39 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:39 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:39 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:40 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:40 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:40 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:41 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:41 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:41 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:41 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:42 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:42 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:42 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:43 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:43 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:43 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:44 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:44 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:44 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:45 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:45 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:45 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:45 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:46 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:46 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:46 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:46 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:47 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 12:13:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:47 - cmdstanpy - INFO - Chain [1] done processing
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1421: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1565: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Users/gracewhyn/Library/Python/3.9/lib/python/site-packages/prophet/forecaster.py:1567: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)

# %%
df_forecast_sample["year"] = df_forecast_sample["tanggal"].dt.year
df_forecast_sample["month"] = df_forecast_sample["tanggal"].dt.month
df_forecast_sample["day"] = df_forecast_sample["tanggal"].dt.day
df_forecast_sample["dayofweek"] = df_forecast_sample["tanggal"].dt.dayofweek
df_forecast_sample["weekofyear"] = df_forecast_sample["tanggal"].dt.isocalendar().week
df_forecast_sample["quarter"] = df_forecast_sample["tanggal"].dt.quarter
df_forecast_sample["is_weekend"] = df_forecast_sample["dayofweek"].isin([5,6]).astype(int)

# %%
df_forecast_sample
# Out:
#        tanggal       pm10       pm25        so2         co         o3  \
# 0   2025-09-01  54.008622  80.691271  24.609263  19.324039  19.575979
# 1   2025-09-02  53.507727  80.298224  24.817371  19.473881  18.922531
# 2   2025-09-03  54.179877  80.475307  25.288162  19.977751  19.207502
# 3   2025-09-04  54.570896  80.422230  25.184700  19.946457  20.047437
# 4   2025-09-05  54.895539  80.376377  24.953556  19.799068  20.369262
# ..         ...        ...        ...        ...        ...        ...
# 450 2025-11-26  20.183393  72.713681  30.257704  10.435453  19.609786
# 451 2025-11-27  19.809239  72.357629  29.964881  10.406793  17.838326
# 452 2025-11-28  19.307386  71.641201  29.948848  10.230931  16.722826
# 453 2025-11-29  18.570588  71.003693  29.742422  10.285027  14.486873
# 454 2025-11-30  17.057974  70.407625  29.361739   9.525654  12.339377
#
#            no2 stasiun
# 0    37.853999    DKI1
# 1    38.782525    DKI1
# 2    39.460974    DKI1
# 3    39.569527    DKI1
# 4    39.120025    DKI1
# ..         ...     ...
# 450  23.166999    DKI5
# 451  23.265550    DKI5
# 452  22.698776    DKI5
# 453  22.116333    DKI5
# 454  21.284813    DKI5
#
# [455 rows x 8 columns]

# %%
print(df_forecast_sample["stasiun"].head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: stasiun, dtype: object

# %%
df_forecast_sample["stasiun"] = df_forecast_sample["stasiun"].astype(int)

X_submit = df_forecast_sample[feature_cols]
y_pred_num = model_xgb.predict(X_submit)
y_pred = le_target.inverse_transform(y_pred_num)

df_forecast_sample["category"] = y_pred

# %%
df_forecast_sample
# Out:
#        tanggal       pm10       pm25        so2         co         o3  \
# 0   2025-09-01  54.008622  80.691271  24.609263  19.324039  19.575979
# 1   2025-09-02  53.507727  80.298224  24.817371  19.473881  18.922531
# 2   2025-09-03  54.179877  80.475307  25.288162  19.977751  19.207502
# 3   2025-09-04  54.570896  80.422230  25.184700  19.946457  20.047437
# 4   2025-09-05  54.895539  80.376377  24.953556  19.799068  20.369262
# ..         ...        ...        ...        ...        ...        ...
# 450 2025-11-26  20.183393  72.713681  30.257704  10.435453  19.609786
# 451 2025-11-27  19.809239  72.357629  29.964881  10.406793  17.838326
# 452 2025-11-28  19.307386  71.641201  29.948848  10.230931  16.722826
# 453 2025-11-29  18.570588  71.003693  29.742422  10.285027  14.486873
# 454 2025-11-30  17.057974  70.407625  29.361739   9.525654  12.339377
#
#            no2  stasiun category
# 0    37.853999        0   SEDANG
# 1    38.782525        0   SEDANG
# 2    39.460974        0   SEDANG
# 3    39.569527        0   SEDANG
# 4    39.120025        0   SEDANG
# ..         ...      ...      ...
# 450  23.166999        4   SEDANG
# 451  23.265550        4   SEDANG
# 452  22.698776        4   SEDANG
# 453  22.116333        4   SEDANG
# 454  21.284813        4   SEDANG
#
# [455 rows x 9 columns]

# %%
(
    df_forecast_sample["category"]
    .value_counts()
    .sort_index()
    .reset_index()
    .rename(columns={"index": "category", "category": "count"})
)
# Out:
#          count  count
# 0         BAIK      5
# 1       SEDANG    449
# 2  TIDAK SEHAT      1

# %%
sample = pd.read_csv("sample_submission.csv")
sample["category"] = y_pred

# %%
sample.head()
sample["category"].value_counts()
# Out:
# category
# SEDANG         449
# BAIK             5
# TIDAK SEHAT      1
# Name: count, dtype: int64

# %%
sample.to_csv("submission5_xgb_prophet.csv", index=False)

# %%
# submission = sample[["id"]].copy()
# submission["category"] = df_forecast_sample["category"].values
# submission = sample[["id", "category"]]
# submission.to_csv("submission5_prophet.csv", index=False)

# %%
pollutant_cols = ["pm10","pm25","so2","co","o3","no2"]

med = df_filled.groupby("stasiun")[pollutant_cols].median().reset_index()
sample = sample.merge(med, on="stasiun", how="left")

# %%
feature_cols = model.feature_names_
X_submit = sample[feature_cols]

sample["category"] = model.predict(X_submit).ravel()

# feature_cols = model.feature_names_
# X_submit = sample[feature_cols]

# pred = model.predict(X_submit).ravel()

# sample["category"] = pred

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
import pickle

model_xgb = XGBClassifier()
model_xgb.load_model("xgb_kategori.json")

# load encoder
le_station = pickle.load(open("le_station.pkl", "rb"))
le_target = pickle.load(open("le_target.pkl", "rb"))

# misal ini data hasil forecasting prophet (sample)
df_sample = df_forecasted.copy()
